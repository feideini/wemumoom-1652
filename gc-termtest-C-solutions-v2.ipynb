# %% [markdown]
# ### MATH 2511 Term Test C Solutions Version 2

# %% [markdown]
# ##### Question 1

# %% [markdown]
# Breathing is cyclic and a full respiratory cycle from the beginning of inhalation to the end of exhalation takes about 5 seconds. The maximum rate of air flow into the lungs is about 0.5 litres per second. This explains, in part, why the function
# $$f(t)=\frac{1}{2}\sin\left(\frac{2\pi}{5}t\right)$$
# has often been used to model the rate of air flow into the lungs. Use this model to find the volume of inhaled air in the lungs at time $t$.

# %% [markdown]
# $$\int{}f(t)\,dt=-\frac{5}{4\pi}\cos\left(\frac{2\pi}{5}t\right)+C$$

# %% [markdown]
# ##### Question 2

# %% [markdown]
# Find the area of the surface generated by revolving about the $y$-axis the arc $C$ given by
# $$
# x=3\sqrt{\frac{y}{2}},1\leq{}y\leq{}2
# $$

# %% [markdown]
# $$A=2\pi\int_{1}^{2}3\sqrt{\frac{y}{2}}\sqrt{1+\frac{9}{8y}}=\frac{\pi}{8}\left[\left(8y+9\right)^{\frac{3}{2}}\right]_{1}^{2}=\frac{\pi}{8}\left(125-\sqrt{7}^{3}\right)$$

# %%
n((pi/8)*(125-7^(3/2)))
# Out:
# 41.8144964405327

# %% [markdown]
# ##### Question 3

# %% [markdown]
# The two curves $y=x$ and $y=x^{3}$ meet three times; call the three points of intersection $A,B,$ and $C$, from left to right. Find the area between the two curves between $A$ and $C$. If part of this area is below the $x$-axis, make sure to *add* it to the total area and not *subtract* it.

# %% [markdown]
# $$\frac{1}{2}A=\int_{0}^{1}(x-x^{3})\,dx=\frac{1}{4}$$

# %% [markdown]
# The area is 0.5 square units.

# %% [markdown]
# ##### Question 4

# %% [markdown]
# $S$ is a solid generated by revolving a bounded region $R$ about the $x$-axis. Find the volume of $S$. $R$ is bounded by the lines $y=0$, $x=\pi/6$, $x=\pi/3$, and the curve $y=\tan{}x$. You may want to use the trigonometric identity $1+\tan^{2}\vartheta=\sec^{2}\vartheta$.

# %% [markdown]
# $$V=\pi\int_{\frac{\pi}{6}}^{\frac{\pi}{3}}\tan^{2}x\,dx=\pi\int_{\frac{\pi}{6}}^{\frac{\pi}{3}}\left(\sec^{2}x-1\right)\,dx=\pi\left[\tan{}x-x\right]_{\frac{\pi}{6}}^{\frac{\pi}{3}}=\pi\left(\sqrt{3}-\frac{1}{\sqrt{3}}-\frac{\pi}{6}\right)=1.982665$$

# %% [markdown]
# ##### Question 5

# %% [markdown]
# Use substitution to evaluate the definite integral$$\int_{4}^{1}\frac{(\sqrt{x}+1)^{4}}{2\sqrt{x}}\,dx$$

# %% [markdown]
# Substitute $u=\sqrt{x}+1$ for $$\int_{4}^{1}\frac{(\sqrt{x}+1)^{4}}{2\sqrt{x}}\,dx=-\frac{1}{5}\left[(\sqrt{x}+1)^{5}\right]_{1}^{4}=-\frac{211}{5}$$

# %% [markdown]
# ##### Question 6

# %% [markdown]
# Find the following arc length.
# $$
# y=\frac{1}{4}x^{5}+\frac{1}{15}x^{-3},2\leq{}x\leq{}3
# $$

# %% [markdown]
# $$\int_{2}^{3}\sqrt{1+\left(\frac{5}{4}x^{4}-\frac{1}{5}x^{-4}\right)^{2}}\,dx=\int_{2}^{3}\left(\frac{5}{4}x^{4}+\frac{1}{5}x^{-4}\right)\,dx=\frac{1}{4}\left(3^{5}-2^{5}\right)-\frac{1}{15}\left(\frac{1}{27}-\frac{1}{8}\right)$$

# %%
n(0.25*(3^5-2^5)-(1/15)*((1/27)-(1/8)))
# Out:
# 52.7558641975309

# %% [markdown]
# ##### Question 7

# %% [markdown]
# Find the length of the following curve.
# $$
# y=\int_{0}^{x}\sqrt{\sec^{4}t-1}\,dt,-\frac{\pi}{4}\leq{}x\leq\frac{\pi}{4}
# $$
# Remember that according to the Fundamental Theorem of Calculus, if $g(x)=\int_{a}^{x}f(t)\,dt$, then $g'(x)=f(x)$.

# %% [markdown]
# $$L=\int_{-\frac{\pi}{3}}^{\frac{\pi}{3}}\sqrt{1+\left(\sqrt{\sec^{4}x-1}\right)^{2}}\,dx=\int_{-\frac{\pi}{3}}^{\frac{\pi}{3}}\sec^{2}x\,dx=\left[\tan{}x\right]_{-\frac{\pi}{4}}^{\frac{\pi}{4}}=2$$
