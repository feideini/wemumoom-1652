# %% [markdown]
# Use matrix arithmetic to find the area of the following triangle: $P=(-2,-5),Q=(4,-3),R=(1,3)$.

# %%
op=vector([-2,-5])

# %%
oq=vector([4,-3])

# %%
orr=vector([1,3])

# %%
pq=oq-op

# %%
pq
# Out:
# (7, 9)

# %%
pr=orr-op

# %%
pr
# Out:
# (3, -2)

# %%
m=matrix([[7,3],[9,-2]])

# %%
(1/2)*det(m)
# Out:
# -41/2

# %% [markdown]
# Use Cramer's rule to find the values of $x_{2}$ and $x_{3}$.
# $$
# \begin{array}{ccccccc}
# x_{1}&+&2x_{2}&+&4x_{3}&=&31\\
# 5x_{1}&+&x_{2}&+&2x_{3}&=&29\\
# 3x_{1}&-&x_{2}&+&x_{3}&=&10
# \end{array}
# $$

# %%
M=matrix([[1,2,4],[5,1,2],[3,-1,1]])

# %%
A=matrix([[1,31,4],[5,29,2],[3,10,1]])

# %%
B=matrix([[1,2,31],[5,1,29],[3,-1,10]])

# %%
x2=det(A)/det(M)

# %%
x2
# Out:
# 4

# %%
x3=det(B)/det(M)

# %%
x3
# Out:
# 5

# %% [markdown]
# Find the determinant of $C$.
# $$
# C=\left[\begin{array}{cccc}
# 1&-2&-3&0\\
# -1&0&0&3\\
# 0&1&3&0\\
# 1&2&0&2
# \end{array}\right]
# $$

# %%
C=matrix([[1,-2,-3,0],[-1,0,0,3],[0,1,3,0],[1,2,0,2]])

# %%
det(C)
# Out:
# -33

# %% [markdown]
# Find the product $AB$.
# $$
# A=\left[\begin{array}{cc}
# 3-3i&6\\
# -5i&-4+7i
# \end{array}\right]\hspace{.5in}
# B=\left[\begin{array}{cc}
# -5-6i&-4+7i\\
# -2+5i&7+2i
# \end{array}\right]
# $$

# %%
A=matrix([[3-3*I,6],[-5*I,-4+7*I]])

# %%
B=matrix([[-5-6*I,-4+7*I],[-2+5*I,7+2*I]])

# %%
A*B
# Out:
# [27*I - 45 45*I + 51]
# [-9*I - 57  61*I - 7]

# %% [markdown]
# Use matrix arithmetic to find the area of the following triangle: $P=(-2,2),Q=(5,4),R=(1,-3)$.

# %%
op=vector([-2,2])

# %%
oq=vector([5,4])

# %%
orr=vector([1,-3])

# %%
pq=oq-op

# %%
pq
# Out:
# (7, 2)

# %%
pr=orr-op

# %%
pr
# Out:
# (3, -5)

# %%
M=matrix([[7,3],[2,-5]])

# %%
(1/2)*det(M)
# Out:
# -41/2

# %% [markdown]
# Use Cramer's rule to find the values of $x_{2}$ and $x_{3}$.
# $$
# \begin{array}{ccccccc}
# x_{1}&+&x_{2}&+&2x_{3}&=&-1\\
# 2x_{1}&-&x_{2}&+&2x_{3}&=&-4\\
# 4x_{1}&+&x_{2}&+&4x_{3}&=&-2
# \end{array}
# $$

# %%
M=matrix([[1,1,2],[2,-1,2],[4,1,4]])

# %%
A=matrix([[1,-1,2],[2,-4,2],[4,-2,4]])

# %%
B=matrix([[1,1,-1],[2,-1,-4],[4,1,-2]])

# %%
det(A)/det(M)
# Out:
# 2

# %%
det(B)/det(M)
# Out:
# -2

# %% [markdown]
# Find the product $AB$.
# $$
# A=\left[\begin{array}{cc}
# 3+3i&6i\\
# -5&-4-7i
# \end{array}\right]\hspace{.5in}
# B=\left[\begin{array}{cc}
# -5+6i&-4-7i\\
# 2-5i&-7+2i
# \end{array}\right]
# $$

# %%
A=matrix([[3+3*I,6*I],[-5,-4-7*I]])

# %%
B=matrix([[-5+6*I,-4-7*I],[2-5*I,-7+2*I]])

# %%
A*B
# Out:
# [  15*I - 3  -75*I - 3]
# [-24*I - 18  76*I + 62]

# %% [markdown]
# Find the determinant of $C$.
# $$
# C=\left[\begin{array}{cccc}
# -2&1&-3&0\\
# 0&1&3&0\\
# -1&0&0&3\\
# 1&2&0&2
# \end{array}\right]
# $$

# %%
C=matrix([[-2,1,-3,0],[0,1,3,0],[-1,0,0,3],[1,2,0,2]])

# %%
det(C)
# Out:
# -66

# %% [markdown]
# Determine how many solutions the following system of equations has. Your answer should be none, one, or infinitely many. Show your work.
# $$
# \begin{array}{ccccccc}
# 4a&-&2b&+&3c&=&2\\
# 5a&+&b&-&2c&=&3\\
# -7a&-&7b&+&12c&=&-5
# \end{array}
# $$

# %%
G=matrix([[4,-2,3,2],[5,1,-2,3],[-7,-7,12,-5]])

# %%
G.echelon_form()
# Out:
# [  1   3  -5   1]
# [  0  14 -23   2]
# [  0   0   0   0]

# %% [markdown]
# Infinitely many solutions.

# %% [markdown]
# Find the three cube roots of $-2028+845i$. Clearly indicate the radius and the angle (in degrees) of your solutions.

# %%
z=(-2028+845*I)^(1/3)

# %%
real_part(z)
# Out:
# 13*cos(1/3*pi - 1/3*arctan(5/12))

# %%
imag_part(z)
# Out:
# 13*sin(1/3*pi - 1/3*arctan(5/12))

# %%
sols=vector([n((1/3*pi - 1/3*arctan(5/12))*180/pi),n(((pi-arctan(5/12)+2*pi)*180/(3*pi))),n(((pi-arctan(5/12)+4*pi)*180/(3*pi)))])

# %%
sols
# Out:
# (52.4600450173199, 172.460045017320, 292.460045017320)

# %% [markdown]
# The following points lie on a parabola $y=ax^{2}+bx+c$: $P=(3,28),Q=(-1,12),R=(2,15)$. Determine the coefficients of the parabola.

# %%
P=matrix([[9,3,1],[1,-1,1],[4,2,1]])

# %%
~P*matrix([[28],[12],[15]])
# Out:
# [ 3]
# [-2]
# [ 7]

# %% [markdown]
# The parabola is $y=3x^{2}-2x+7$.

# %% [markdown]
# Determine how many solutions the following system of equations has. Your answer should be none, one, or infinitely many. Show your work.
# $$
# \begin{array}{ccccccc}
# -4x&+&2y&+&6z&=&4\\
# 8x&-&8y&-&z&=&2\\
# -4x&-&2y&+&17z&=&9
# \end{array}\notag
# $$

# %%
M=matrix([[-4,2,6,4],[8,-8,-1,2],[-4,-2,17,9]])

# %%
M.echelon_form()
# Out:
# [  4   2 -17   1]
# [  0   4 -11   0]
# [  0   0   0   5]

# %% [markdown]
# No solutions.

# %% [markdown]
# Convert the following complex number to polar form:
# $$\frac{-2+2i}{5+i}$$

# %%
z=(-2+2*I)/(5+I)

# %%
real_part(z)
# Out:
# -4/13

# %%
imag_part(z)
# Out:
# 6/13

# %%
abs(z)
# Out:
# 2*sqrt(1/13)

# %%
arg(z)
# Out:
# pi - arctan(3/2)

# %% [markdown]
# The following points lie on a parabola $y=ax^{2}+bx+c$: $P=(1,4),Q=(-3,40),R=(-2,16)$. Determine the coefficients of the parabola.

# %%
P=matrix([[1,1,1],[9,-3,1],[4,-2,1]])

# %%
~P*matrix([[4],[40],[16]])
# Out:
# [ 5]
# [ 1]
# [-2]

# %% [markdown]
# The parabola is $y=5x^{2}+x-2$.

# %% [markdown]
# Find the three cube roots of $-100-75i$. Clearly indicate the radius and the angle (in degrees) of your solutions.

# %%
z=-100-75*I

# %%
abs(z)
# Out:
# 125

# %%
n(abs(z)^(1/3))
# Out:
# 5.00000000000000

# %%
arg(z)
# Out:
# -pi + arctan(3/4)

# %%
n((-pi + arctan(3/4))*180/pi)
# Out:
# -143.130102354156

# %%
n((-pi + arctan(3/4))*180/pi)+360
# Out:
# 216.869897645844

# %%
n((-pi + arctan(3/4))*180/pi)+240
# Out:
# 96.8698976458440

# %%
n((-pi + arctan(3/4))*180/pi)+480
# Out:
# 336.869897645844

# %% [markdown]
# Convert the following complex number to polar form: $$\frac{3-3i}{-4+i}$$

# %%
z=(3-3*I)/(-4+I)

# %%
real_part(z)
# Out:
# -15/17

# %%
imag_part(z)
# Out:
# 9/17

# %%
abs(z)
# Out:
# 3*sqrt(2/17)

# %%
n(abs(z))
# Out:
# 1.02899151085505

# %%
arg(z)
# Out:
# pi - arctan(3/5)

# %%
n(arg(z)*180/pi)
# Out:
# 149.036243467926

# %% [markdown]
# Determine how many solutions the following system of equations has. Your answer should be none, one, or infinitely many. Show your work.
# $$
# \begin{array}{ccccccc}
# 3x&+&4y&-&8z&=&-6\\
# -x&+&3y&+&6z&=&7\\
# x&+&10y&+&4z&=&-3
# \end{array}
# $$

# %%
M=matrix([[3,4,-8,-6],[-1,3,6,7],[1,10,4,-3]])

# %%
M.echelon_form()
# Out:
# [ 1 10  4  8]
# [ 0 13 10  4]
# [ 0  0  0 11]

# %% [markdown]
# No solutions.

# %% [markdown]
# Determine how many solutions the following system of equations has. Your answer should be none, one, or infinitely many. Show your work.$$
# \begin{array}{ccccccc}
# 2a&+&3b&+&7c&=&-1\\
# 4a&-&2b&-&2c&=&3\\
# 8a&-&12b&-&20c&=&11
# \end{array}
# $$

# %%
M=matrix([[2,3,7,-1],[4,-2,-2,3],[8,-12,-20,11]])

# %%
M.echelon_form()
# Out:
# [ 2  3  7 -1]
# [ 0  8 16 -5]
# [ 0  0  0  0]

# %% [markdown]
# Infinitely many solutions.
